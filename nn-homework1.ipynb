# %% [markdown]
# <a href="https://www.kaggle.com/code/salmix1326/nn-homework1?scriptVersionId=292423380" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Ваша задача методом градієнтного спуску побудувати модель для прогнозу ціни на діаманти

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/diamonds.csv",
                 index_col=0)

df.head()
# Out:
#    carat  price
# 0   0.23    326
# 1   0.21    326
# 2   0.23    327
# 3   0.29    334
# 4   0.31    335

# %% [markdown]
# Формула моделі
# $$
#           pred = coef*carat + intercept
# $$
# * coef - ціна за один карат
# * intercept - витрати
#
#
# <br>
# <br>
# Формула для ображунку похибки
#
# $$
#           loss = mean((pred - price)^2)
# $$
#
# * pred - ціна, спрогнозована моделю
# * price - справжня ціна

# %%
# імпорт модуля
import torch


carat = df['carat'].to_numpy()
price = df['price'].to_numpy()

# вага в каратах
carat = torch.tensor(carat, dtype=torch.float32)

# справжня ціна
price = torch.tensor(price, dtype=torch.float32)

# %%
from torch.optim import SGD

# підкоючаємо процесор
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# створіть тензори з градієнтом, оберіть довільне початкове значення, тип даних float32
coef = torch.tensor(0.5, requires_grad=True, dtype=torch.float32)
intercept = torch.tensor(320, requires_grad=True, dtype=torch.float32)

# вкажіть навчальний крок
learning_rate = 0.01

# визначення оптимізатора
optimizer = SGD(
    [coef, intercept],   # список параметрів(тензори з градієнтом)
    lr = learning_rate
)

# основний цикл
for t in range(4000):
  # обрахуйте прогноз моделі за формулою наведеною вище
    pred = coef*carat+intercept
  # обрахуйте похибку між справжньою ціною та прогнозованою
    loss = torch.mean((pred - price) ** 2)
  # виведіть значення похибки для кожного сотого кроку
    if t % 100 == 0:
        print(f"Loss:{loss.item()}")
        print(f"Coef:{coef.item()}")
        print(f"Intercept:{intercept.item()}")
  # обрахуйте градієнти по метриці
    loss.backward()
  # градієнтний спуск
    optimizer.step()
    optimizer.zero_grad()
# Out:
# Loss:28963032.0
# Coef:0.5
# Intercept:320.0
# Loss:6706524.5
# Coef:3450.823486328125
# Intercept:1557.8778076171875
# Loss:4950335.0
# Coef:4485.41845703125
# Intercept:738.9227905273438
# Loss:3915874.0
# Coef:5235.36083984375
# Intercept:55.11286544799805
# Loss:3300678.0
# Coef:5812.2861328125
# Intercept:-473.7635192871094
# Loss:2934815.25
# Coef:6257.154296875
# Intercept:-881.6641845703125
# Loss:2717232.0
# Coef:6600.224609375
# Intercept:-1196.2281494140625
# Loss:2587832.5
# Coef:6864.7919921875
# Intercept:-1438.812744140625
# Loss:2510877.25
# Coef:7068.81982421875
# Intercept:-1625.887939453125
# Loss:2465111.25
# Coef:7226.16064453125
# Intercept:-1770.15576171875
# Loss:2437893.5
# Coef:7347.49853515625
# Intercept:-1881.41162109375
# Loss:2421707.0
# Coef:7441.072265625
# Intercept:-1967.209716796875
# Loss:2412080.75
# Coef:7513.232421875
# Intercept:-2033.3741455078125
# Loss:2406355.75
# Coef:7568.880859375
# Intercept:-2084.39892578125
# Loss:2402951.25
# Coef:7611.796875
# Intercept:-2123.748291015625
# Loss:2400926.0
# Coef:7644.89208984375
# Intercept:-2154.09423828125
# Loss:2399721.75
# Coef:7670.41455078125
# Intercept:-2177.49609375
# Loss:2399005.75
# Coef:7690.09375
# Intercept:-2195.541259765625
# Loss:2398580.0
# Coef:7705.27294921875
# Intercept:-2209.4580078125
# Loss:2398326.75
# Coef:7716.97802734375
# Intercept:-2220.190185546875
# Loss:2398176.0
# Coef:7726.00537109375
# Intercept:-2228.468017578125
# Loss:2398086.25
# Coef:7732.96630859375
# Intercept:-2234.85009765625
# Loss:2398033.25
# Coef:7738.33447265625
# Intercept:-2239.77294921875
# Loss:2398001.5
# Coef:7742.47412109375
# Intercept:-2243.568115234375
# Loss:2397982.5
# Coef:7745.66552734375
# Intercept:-2246.49462890625
# Loss:2397971.75
# Coef:7748.12744140625
# Intercept:-2248.752197265625
# Loss:2397964.75
# Coef:7750.0263671875
# Intercept:-2250.493408203125
# Loss:2397960.75
# Coef:7751.490234375
# Intercept:-2251.83544921875
# Loss:2397958.5
# Coef:7752.61865234375
# Intercept:-2252.8701171875
# Loss:2397957.0
# Coef:7753.4892578125
# Intercept:-2253.668212890625
# Loss:2397956.25
# Coef:7754.1591796875
# Intercept:-2254.282958984375
# Loss:2397955.5
# Coef:7754.6767578125
# Intercept:-2254.757568359375
# Loss:2397955.5
# Coef:7755.07373046875
# Intercept:-2255.12255859375
# Loss:2397955.25
# Coef:7755.38330078125
# Intercept:-2255.403076171875
# Loss:2397955.25
# Coef:7755.61572265625
# Intercept:-2255.6201171875
# Loss:2397955.25
# Coef:7755.7978515625
# Intercept:-2255.787109375
# Loss:2397955.5
# Coef:7755.94091796875
# Intercept:-2255.913818359375
# Loss:2397955.25
# Coef:7756.04150390625
# Intercept:-2256.011474609375
# Loss:2397955.0
# Coef:7756.13037109375
# Intercept:-2256.087890625
# Loss:2397954.75
# Coef:7756.1865234375
# Intercept:-2256.1455078125

# %% [markdown]
# # Результат

# %%
coef.item(), intercept.item()
# Out:
# (7756.2353515625, -2256.1904296875)

# %% [markdown]
# # Порівняйте результат з sklearn

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
X_train = df.drop(columns=['price'])
y_train = df['price']
# тренування
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_[0], model.intercept_
# Out:
# (np.float64(7756.425617968435), np.float64(-2256.360580045403))
